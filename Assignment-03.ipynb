# %% [markdown]
# # Matplotlib

# %% [markdown]
# The following imports numpy.  Do similar imports for matplotlib.pyplot and pandas:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
# %matplotlib inline

# %% [markdown]
# 𝑦(𝑥)=4+2𝑥−𝑥2+0.075𝑥3We're going to generate some plots of fictitious data that follow this equation:
#
# $$ y(x) = 4 + 2x - x^2 + 0.075x^3 $$
#
# The following cell generates our `x` and `y` arrays.

# %%
x = np.linspace(0, 10, 50)
y = 4 + 2*x - x**2 + 0.075*x**3

# %% [markdown]
# Use the matplotlib.pyplot module to make a plot of `y` against `x` (y vertically, x horizontally):

# %%
plt.ylabel('y-axis',fontsize=16)
plt.xlabel('x -axis',fontsize=16)
plt.title('Plotting Y vs X',fontsize=16)
plt.plot(x,y, color='blue',marker = '*')
plt.grid()
plt.show()

# %% [markdown]
# (Check your ranges in the plot to make sure that `x` values are plotted horizontally and `y` values are plotted vertically.)

# %% [markdown]
# Real data is usually noisy.  It may be noise from measurement, or "noise" in the sense that there are aspects of the data that aren't captured by the features that we measure.
#
# The following cell introduces some random noise into a new variable `y_with_noise` that equals `y + noise`

# %%
# generate 50 points from a normal 
# distribution that has mean = 0 and std dev = 1.5
noise = np.random.normal(0,1.5,50)

# this y is now the theoretical value + noise
y_with_noise = 4 + 2*x - x**2 + 0.075*x**3 + noise

# %% [markdown]
# Make a plot of y_with_noise against x:

# %%
plt.plot(x,y_with_noise)
plt.grid()
plt.show()

# %% [markdown]
# Make a figure that includes
# * scatter plot of y_with_noise against x
# * line plot of y against x

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(x,y_with_noise)
ax.plot(x,y)
plt.show()

# %% [markdown]
# Make the same plot again with:
# * labels for the x-axis and y-axis
# * a title
# * 16-pt font size for the labels and title
# * make the line blue
# * make the scatter points black

# %%
plt.xlabel('X',fontsize=16)
plt.ylabel('Y & Y-Noise',fontsize=16)
plt.title('Y vs X & Y-Noise vs X',fontsize=16)
plt.scatter(x,y_with_noise,color='black')
plt.plot(x,y,color ='blue')

# %% [markdown]
# Save the figure into a file named 'matplotlib-plot.png':

# %%
#saving the plot as .png
plt.xlabel('X',fontsize=16)
plt.ylabel('Y & Y-Noise',fontsize=16)
plt.title('Y vs X & Y-Noise vs X',fontsize=16)
plt.scatter(x,y_with_noise,color='black')
plt.plot(x,y,color ='blue')
plt.savefig("matplotlib-plot.png") 
plt.show()

# %% [markdown]
# Generate the same plot using the figure and axes objects (you can use the matplotlib.pyplot module to generate the figure, but otherwise don't use matplotlib.pyplot.)
#
# * The documentation for matplotlib.axes -> https://matplotlib.org/stable/api/axes_api.html
# * The documentation for matplotlib.figure -> https://matplotlib.org/stable/api/figure_api.html
#
# Save the figure into the file 'figure-plot.png'

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.title('Y vs X',fontsize=16)
ax.scatter(x,y_with_noise,color='black')
ax.plot(x,y,color = 'blue')
plt.savefig("figure-plot.png")
plt.show()

# %% [markdown]
# # Pandas

# %% [markdown]
# Use pandas to import the data from 'anscombe.csv' into a dataframe variable

# %%
#importing anscombe.csv file into pandas data frame
combedata = pd.read_csv('anscombe.csv')
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %% [markdown]
# Print the first 2 rows of the dataframe:

# %%
#printing first 2 rows of data ussing head()
combedata.head(2)
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95

# %% [markdown]
# Print the last 2 rows of the dataframe:

# %%
#printing last 2 rows of data ussing tail()
combedata.tail(2)

# %% [markdown]
# Print the number of rows and columns of the dataframe:

# %%
#printing the no of rows and columns of the data frame using shape function
combedata.shape
# Out:
# (44, 3)

# %% [markdown]
# Print the column names of the dataframe:

# %%
#printing the columns names of the data frame using columns function
combedata.columns
# Out:
# Index(['dataset', 'x', 'y'], dtype='object')

# %% [markdown]
# Print the datatypes of each column:

# %%
#printing datatype of each column using dtypes function
combedata.dtypes
# Out:
# dataset     object
# x          float64
# y          float64
# dtype: object

# %% [markdown]
# Print summary statistics about the dataframe:

# %%
#Printing summary of statistics about the dataframe using describe()
combedata.describe()
# Out:
#                x          y
# count  44.000000  44.000000
# mean    9.000000   7.500682
# std     3.198837   1.958925
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %% [markdown]
# Print the values that are in the 'dataset' column:

# %%
#Print the values that are in the 'dataset' column:
combedata['dataset']
# Out:
# 0       I
# 1       I
# 2       I
# 3       I
# 4       I
# 5       I
# 6       I
# 7       I
# 8       I
# 9       I
# 10      I
# 11     II
# 12     II
# 13     II
# 14     II
# 15     II
# 16     II
# 17     II
# 18     II
# 19     II
# 20     II
# 21     II
# 22    III
# 23    III
# 24    III
# 25    III
# 26    III
# 27    III
# 28    III
# 29    III
# 30    III
# 31    III
# 32    III
# 33     IV
# 34     IV
# 35     IV
# 36     IV
# 37     IV
# 38     IV
# 39     IV
# 40     IV
# 41     IV
# 42     IV
# 43     IV
# Name: dataset, dtype: object

# %% [markdown]
# Use "loc" to print the first 10 rows:

# %%
#printing the first 10 rows using "loc"  function
combedata.loc[0:9]
# Out:
#   dataset     x      y
# 0       I  10.0   8.04
# 1       I   8.0   6.95
# 2       I  13.0   7.58
# 3       I   9.0   8.81
# 4       I  11.0   8.33
# 5       I  14.0   9.96
# 6       I   6.0   7.24
# 7       I   4.0   4.26
# 8       I  12.0  10.84
# 9       I   7.0   4.82

# %% [markdown]
# Use "loc" to print the values from the first 10 rows of the 'x' column:

# %%
#printing first 10 rows of the x column using loc function
combedata['x'].loc[0:9]
# Out:
# 0    10.0
# 1     8.0
# 2    13.0
# 3     9.0
# 4    11.0
# 5    14.0
# 6     6.0
# 7     4.0
# 8    12.0
# 9     7.0
# Name: x, dtype: float64

# %% [markdown]
# Use "loc" to print the rows for which `dataset` is equal to `III`:

# %%
combedata.loc[combedata['dataset']=='III']
# Out:
#    dataset     x      y
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73

# %% [markdown]
# Make a line plot of y against x for dataset III:

# %%
x3=combedata['x'].loc[combedata['dataset']=='III']
y3= combedata['y'].loc[combedata['dataset']=='III']
plt.plot(x3,y3)
plt.xlabel('x',fontsize=16)
plt.ylabel('y',fontsize=16)
plt.title('X vs Y for dataset = III-Line plot')
plt.show()

# %% [markdown]
# Make a scatter plot of y against x for dataset III:

# %%
plt.scatter(x3,y3)
plt.xlabel('x',fontsize=16)
plt.ylabel('y',fontsize=16)
plt.title('X vs Y for dataset = III- Scatter Plot')
plt.show()

# %% [markdown]
# Make scatter plots for the other 3 datasets:

# %%
x1=combedata['x'].loc[combedata['dataset']=='I']
y1= combedata['y'].loc[combedata['dataset']=='I']
plt.scatter(x1,y1)
plt.xlabel('x1',fontsize=16)
plt.ylabel('y1',fontsize=16)
plt.title('X vs Y for dataset = I- Scatter Plot')
plt.show()
x2=combedata['x'].loc[combedata['dataset']=='II']
y2= combedata['y'].loc[combedata['dataset']=='II']
plt.scatter(x2,y2)
plt.xlabel('x2',fontsize=16)
plt.ylabel('y2',fontsize=16)
plt.title('X vs Y for dataset = II- Scatter Plot')
plt.show()
x4=combedata['x'].loc[combedata['dataset']=='IV']
y4= combedata['y'].loc[combedata['dataset']=='IV']
plt.scatter(x4,y4)
plt.xlabel('x4',fontsize=16)
plt.ylabel('y4',fontsize=16)
plt.title('X vs Y for dataset = IV- Scatter Plot')
plt.show()

# %% [markdown]
# We're working with the datasets from Anscombe's quartet.  You can read about it [here](https://en.wikipedia.org/wiki/Anscombe%27s_quartet).
#
# Use that page to find the equation for the linear regression line of these datasets, and make a figure that includes:
# * a scatter plot of dataset I
# * a line plot of the linear regression line

# %%
x1=combedata['x'].loc[combedata['dataset']=='I']
y1= combedata['y'].loc[combedata['dataset']=='I']
#linear regression line equation
yr = 3.00 + 0.500*x1
plt.scatter(x1,y1,color='red')
plt.plot(x1,yr, color = 'black')
plt.show()

# %% [markdown]
# Make the same plot again with:
# * a title
# * 16-pt font size for the labels and title
# * make the line blue
# * make the scatter points black
# * save the figure into a file called 'anscombe-I.png'

# %%
plt.scatter(x1,y1,color='black')
plt.xlabel('x1',fontsize=16)
plt.ylabel('y1',fontsize=16)
plt.title('Scatter Plot vs Linear regression for dataset I', fontsize=16)
plt.plot(x1,yr, color = 'blue')
plt.savefig("anscombe-I.png")
plt.show()

# %% [markdown]
# # End
